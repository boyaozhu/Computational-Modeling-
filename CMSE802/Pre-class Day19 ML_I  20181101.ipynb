# %% [markdown]
# # CMSE 802 Pre-class assignment: Machine Learning
# ## Date: 10/30/2018
# ## Due: 11/01/2018; 10:30 PM
#
# ### The goal of this assignment is to introduce some basics of machine learning.

# %% [markdown]
# ---
# ### Your name: Boyao Zhu

# %% [markdown]
# ----
# ### 1. Introduction to Machine Learning
# Watch the following video and answer the questions below.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("f7YB73F0zDo",width=640,height=360)

# %% [markdown]
# **Question 1:** What is the difference between Supervised and Unsupervised machine learning?

# %% [markdown]
# **Your answer: ** Supervised have labels while Unsupervised comes with no labels

# %% [markdown]
# **Question 2:** What is the difference between Regression and Classification models?

# %% [markdown]
# **Your answer: **
# Classification is the task of predicting a discrete class label.
# Regression is the task of predicting a continuous quantity.

# %% [markdown]
# **Question 3:** Investigate what machine learning libraries are available for Python (Name at least two)?

# %% [markdown]
# **Your answer: ** scikit learn, tensor flow

# %% [markdown]
# ---
# ### 2. Introduction to Support Vector Machines
# One type of supervised classification algorithm that is commonly used is Support Vector Machines. Please watch the following video:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("Zw3FClKgJaM",width=640,height=360)

# %% [markdown]
# Here, let's get some hands-on experiences on SVM.
#
# ---
# **Problem set up: ** We have two set of data. Set 1: x1 = [ 1, 1.5 ,1] and y1 = [ 2, 1.8 ,0.6], and Set 2: x2 = [ 5, 8, 9] and y2 = [ 8, 8, 11]. For a data point xp = 4 and yp = 3.8, which group this data point should be classified to?

# %% [markdown]
# **A. Load libraries. **

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# **B. Plot all data points using plt.scatter( ). By eyeballing the data points, determine  the point [xp, yp] belonging to which of Set 1 or Set 2. **

# %%
# Your code: 
x1 = [1,1.5,1]
y1 = [2,1.8,0.6]
x2 = [5,8,9]
y2 = [8,8,11]
xp = 4
yp = 3.8
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.scatter(xp,yp)
plt.show()

# %% [markdown]
# **Your answer: ** by eyeballing the data point, (xp,yp) belongs to blue group.

# %% [markdown]
# ---
# **C. Follow the "Examples" in the link below. Create an array X that contains the coordinates of points of Set 1 and Set 2. Similarly, creates an array y that contains the group labels of Set 1 and Set 2.  Note that, in the "Examples", X contains the coordinates of 4 points, and y contains the labels of groups for the 4 points.  **
#
# http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
# Your code:
import numpy as np
X = np.array([[1,2],[1.5,1.8],[1,0.6],[5,8],[8,8],[9,11]])
y = np.array([1,1,1,2,2,2])

# %% [markdown]
# ---
# **D. Load library of SVM, and call the classifier.**

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear', C=1.0)

# %% [markdown]
# ---
# **E. Follow the "Examples" in the previous link. Use clf.fit( ) funciton to do the SVM classification. **

# %%
# Your code:
clf.fit(X,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ---
# **F. Plot the result of dividing line. **

# %%
# plotting the SVC dividing line

w = clf.coef_[0]
print(w)

a = -w[0] / w[1]

xx = np.linspace(0,12)
yy = a * xx - clf.intercept_[0] / w[1]

h0 = plt.plot(xx, yy, 'k-', label="non weighted div")

plt.scatter(X[:, 0], X[:, 1], c = y)
# plt.axis('equal')
plt.legend()
plt.scatter(xp,yp)
plt.show()

print(clf.predict([[-0.8,-1]]))
# Out:
# [0.1380943  0.24462418]
# [1]

# %% [markdown]
# **Question 4: Which of Set 1 or Set 2 the data point [xp, yp] is classified to? Is your earlier classification by eyeballing correct? **

# %% [markdown]
# **Your answer: ** Set 1. Yes

# %% [markdown]
# ** Question 5: Pick one of your libraries from the your investigation in Section 1. Copy and paste the example code you found, and run it in the cell below.   Let's not worry about understanding the example yet.  Just see if you can get something to work that seems to be doing some sort of machine learning. **
#
# **Don't forget to indicate where the code is from. **

# %%
# Put your example code here (Include a reference link)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
Y = iris.target

logreg = LogisticRegression(C=1e5, solver='lbfgs', multi_class='multinomial')

# we create an instance of Neighbours Classifier and fit the data.
logreg.fit(X, Y)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(4, 3))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()

# %%
#  http://scikit-learn.org/stable/auto_examples/linear_model/plot_iris_logistic.html

# %% [markdown]
# ### Congratulations, you're done with your first pre-class assignment!
#
# Now, you just need to submit this assignment by uploading it to the course Desire2Learn web page.  Go to Assessments > Assignments, find the link for Pre-class assignment 20181131, and upload it there.
#
#
# See you in class!
