# %% [markdown]
# # CMSE 802 Pre-class assignment: Artificial Neutral Networks (ANN) Part 3
# ## Date: 11/13/2018
# ## Due: 11/14/2018; 10:30 PM
#
# ### The goal of this assignment is to learn using existing ANN libraries.

# %% [markdown]
# ---
# ### Your name: Boyao

# %% [markdown]
# ---
# ### Activity 1:
#
# Andrew Ng is one of the super stars in the world of machine learning. He's an adjunct professor of Computer Science at Stanford University, co-funder of the online learning platform Coursera and former Chief Scientist at Baidu (China's Google).
#
#
# Watch the following video from 21:35 to 30:20. Of course I encourage you to watch the whole thing, it's pretty interesting!

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('F1ka6a13S9I',width=640,height=360)

# %% [markdown]
# ### Activity 2:
#
# After training a neural network you get the following profile of mean-squarred error:
#
# human_error = 0.89
#
# training_error = 10.05
#
# validation_error = 10.95
#
# testing_error = 11.07
#
# **Question: What steps would you follow to improve results? **

# %% [markdown]
# **Your answer: ** This is high bias.
# we will use bigger model, train longer or new model architecture

# %% [markdown]
# ---
#
# ### Activity 3:
#
# In the coming class, we are going to use a machine learning application programming interface (API), Keras, which is one of the most commonly used modules for machine learning applications in the community.

# %% [markdown]
# Watch the video for some introduction of Keras in the cell below.

# %%
YouTubeVideo('j_pJmXJwMLA',width=640,height=360)

# %% [markdown]
# **Go to Keras website (https://keras.io/) and investigate what Keras is.**

# %% [markdown]
# **Question: What are the backend engines that Keras can run on? Who are the developers of the those backend engines?**

# %% [markdown]
# **Your answer: ** specialized, well-optimized tensor manipulation library
#
# the TensorFlow backend, the Theano backend, and the CNTK backend.

# %% [markdown]
# Next, we need to install Keras with its backend engine. I installed TensorFlow on my Mac for this task, following the instruction on the webpage linked below.
#
# https://www.dataweekends.com/blog/2017/03/09/set-up-your-mac-for-deep-learning-with-python-keras-and-tensorflow
#
# The installation for Windows should be similar. You should be able to find many instructions on the internet. You are not limited to installing one specific backend engine, as long as Keras can run on your computer.

# %% [markdown]
# **After installation, you need to test whether the installation is successful. As on webpage above, you can import keras and tensorflow to check whether the library is functioning. **

# %%
# test whether you can access the libraries of Keras and the backend engine you chose

import keras # <== fill the blank
import tensorflow
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ---
# ### Congratulations, you're done with the pre-class assignment!
#
# Now, you just need to submit this assignment by uploading it to the course Desire2Learn web page.  Go to Assessments > Assignments, find the link for Pre-class assignment 20181114, and upload it there.
#
# **Please keep a copy the code. We will reuse the code in the class.**
#
# See you in class!
